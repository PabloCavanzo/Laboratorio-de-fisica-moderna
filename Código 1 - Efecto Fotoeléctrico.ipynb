# %% [markdown]
# <a href="https://colab.research.google.com/github/PabloCavanzo/Laboratorio-de-fisica-moderna/blob/main/C%C3%B3digo%201%20-%20Efecto%20Fotoel%C3%A9ctrico.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np

# %%
import matplotlib.pyplot as plt
import os
from google.colab import drive
drive.mount('/content/drive', force_remount=True)
# Out:
# Mounted at /content/drive

# %%
os.chdir('/content/drive/MyDrive/Colab/Lab de Moderna/Exp. 1 - Efecto fotoelectrico')
# !ls
# Out:
# 'Código 1 - Efecto Fotoeléctrico.ipynb'
# 'Datos_EfectoFotoelectrico - Parte 1 (Amarillo) (1).csv'
# 'Datos_EfectoFotoelectrico - Parte 1 (Azul).csv'
# 'Datos_EfectoFotoelectrico - Parte 1 (Rojo).csv'
# 'Datos_EfectoFotoelectrico - Parte 1 (Verde).csv'
# 'Datos experimento fotoeléctrico-Parte2.xlsx'

# %%
filea = '/content/drive/MyDrive/Colab/Lab de Moderna/Exp. 1 - Efecto fotoelectrico/Datos_EfectoFotoelectrico - Parte 1 (Amarillo) (1).csv'

# %%
data_yellow = pd.read_csv(filea, usecols=['V(V)', 'I(nA)'])
data_yellow = data_yellow[1:]
data_yellow
# Out:
#     I(nA)   V(V)
# 1      95 -0.223
# 2      90 -0.230
# 3      85 -0.235
# 4      80 -0.241
# 5      75 -0.248
# 6      70 -0.254
# 7      65 -0.261
# 8      60 -0.266
# 9      55 -0.274
# 10     50 -0.282
# 11     45 -0.290
# 12     40 -0.301
# 13     35 -0.311
# 14     30 -0.321
# 15     25 -0.336
# 16     20 -0.350
# 17     15 -0.367
# 18     10 -0.383
# 19      5 -0.408
# 20      0 -0.442

# %%
current_yellow = data_yellow["I(nA)"]
potential_yellow = data_yellow["V(V)"]
errores_amarillo = np.full(len(current_yellow), 0.001)

plt.errorbar(potential_yellow, current_yellow, yerr=errores_amarillo, fmt='o', color='y', capsize=3)
plt.scatter(potential_yellow, current_yellow, color='y')
plt.xlabel("Voltaje (V)")
plt.ylabel("Corriente (nA)")
plt.title("Voltaje vs Corriente LED Amarillo")
plt.legend(["Datos LED Amarillo"])
plt.grid(alpha=0.6)

# %%
fileb = '/content/drive/MyDrive/Colab/Lab de Moderna/Exp. 1 - Efecto fotoelectrico/Datos_EfectoFotoelectrico - Parte 1 (Rojo).csv'

# %%
data_red = pd.read_csv(fileb, usecols=['V(V)', 'I(nA)'])
data_red = data_red[1:]
data_red
# Out:
#     I(nA)   V(V)
# 1      95 -0.161
# 2      90 -0.168
# 3      85 -0.172
# 4      80 -0.176
# 5      75 -0.179
# 6      70 -0.184
# 7      65 -0.189
# 8      60 -0.193
# 9      55 -0.197
# 10     50 -0.201
# 11     45 -0.207
# 12     40 -0.214
# 13     35 -0.219
# 14     30 -0.226
# 15     25 -0.233
# 16     20 -0.243
# 17     15 -0.253
# 18     10 -0.263
# 19      5 -0.276
# 20      0 -0.291

# %%
current_red = data_red["I(nA)"]
potential_red = data_red["V(V)"]
errores_rojo = np.full(len(current_red), 0.001)

plt.errorbar(potential_red, current_red, yerr=errores_rojo, fmt='o', color='r', capsize=3)
plt.scatter(potential_red, current_red, color = 'r')
plt.xlabel("Voltaje (V)")
plt.ylabel("Corriente (nA)")
plt.title("Voltaje vs Corriente LED Rojo")
plt.legend(["Datos LED Rojo"])
plt.grid(alpha=0.6)

# %%
filec = '/content/drive/MyDrive/Colab/Lab de Moderna/Exp. 1 - Efecto fotoelectrico/Datos_EfectoFotoelectrico - Parte 1 (Azul).csv'

# %%
data_azul = pd.read_csv(filec, usecols=['V(V)', 'I(nA)'])
data_azul = data_azul[1:]
data_azul
# Out:
#     I(nA)   V(V)
# 1      95 -0.696
# 2      90 -0.697
# 3      85 -0.698
# 4      80 -0.699
# 5      75 -0.699
# 6      70 -0.700
# 7      65 -0.701
# 8      60 -0.702
# 9      55 -0.703
# 10     50 -0.703
# 11     45 -0.704
# 12     40 -0.705
# 13     35 -0.706
# 14     30 -0.706
# 15     25 -0.707
# 16     20 -0.708
# 17     15 -0.708
# 18     10 -0.709
# 19      5 -0.710
# 20      0 -0.711

# %%
current_azul = data_azul["I(nA)"]
potential_azul = data_azul["V(V)"]
errores_azul = np.full(len(current_azul), 0.001)

plt.errorbar(potential_azul, current_azul, yerr=errores_azul, fmt='o', color='b', capsize=3)
plt.scatter(potential_azul, current_azul)
plt.xlabel("Voltaje (V)")
plt.ylabel("Corriente (nA)")
plt.title("Voltaje vs Corriente LED Azul")
plt.legend(["Datos LED Azul"])
plt.grid(alpha=0.6)

# %%
filed = '/content/drive/MyDrive/Colab/Lab de Moderna/Exp. 1 - Efecto fotoelectrico/Datos_EfectoFotoelectrico - Parte 1 (Verde).csv'

# %%
data_verde = pd.read_csv(filed, usecols=['V(V)', 'I(nA)'])
data_verde = data_verde[1:]
data_verde
# Out:
#     I(nA)   V(V)
# 1      95 -0.587
# 2      90 -0.588
# 3      85 -0.591
# 4      80 -0.592
# 5      75 -0.594
# 6      70 -0.597
# 7      65 -0.599
# 8      60 -0.600
# 9      55 -0.601
# 10     50 -0.604
# 11     45 -0.606
# 12     40 -0.608
# 13     35 -0.610
# 14     30 -0.612
# 15     25 -0.614
# 16     20 -0.616
# 17     15 -0.619
# 18     10 -0.622
# 19      5 -0.624
# 20      0 -0.627

# %%
current_verde = data_verde["I(nA)"]
potential_verde = data_verde["V(V)"]
errores_verde = np.full(len(current_verde), 0.001)

plt.errorbar(potential_verde, current_verde, yerr=errores_verde, fmt='o', color='g', capsize=3)
plt.scatter(potential_verde, current_verde, color='g')
plt.xlabel("Voltaje (V)")
plt.ylabel("Corriente (nA)")
plt.title("Voltaje vs Corriente LED Verde")
plt.legend(["Datos LED Verde"])
plt.grid(alpha=0.6)
