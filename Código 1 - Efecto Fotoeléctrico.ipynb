# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
data_yellow = pd.read_excel(r"C:\Users\LENOVO\Documents\Computador Nuevo JP\UNIANDES\CUARTO SEMESTRE\LAB. FISICA MODERNA\Datos 1 - Efecto Fotoeléctrico (Parte 1) - copia.xlsx")
data_yellow
# Out:
#     I(nA)   V(V)
# 0      95 -0.223
# 1      90 -0.230
# 2      85 -0.235
# 3      80 -0.241
# 4      75 -0.248
# 5      70 -0.254
# 6      65 -0.261
# 7      60 -0.266
# 8      55 -0.274
# 9      50 -0.282
# 10     45 -0.290
# 11     40 -0.301
# 12     35 -0.311
# 13     30 -0.321
# 14     25 -0.336
# 15     20 -0.350
# 16     15 -0.367
# 17     10 -0.383
# 18      5 -0.408
# 19      0 -0.442

# %%
current_yellow = data_yellow["I(nA)"]
potential_yellow = data_yellow["V(V)"]
plt.scatter(potential_yellow, current_yellow)
plt.xlabel("Voltaje (V)")
plt.ylabel("Corriente (nA)")
plt.title("Voltaje vs Corriente LED Amarillo")
# Out:
# Text(0.5, 1.0, 'Voltaje vs Corriente LED Amarillo')

# %%
data_red = pd.read_excel(r"C:\Users\LENOVO\Documents\Computador Nuevo JP\UNIANDES\CUARTO SEMESTRE\LAB. FISICA MODERNA\Datos 1 - Efecto Fotoeléctrico (Parte 1) - copia.xlsx",1)
data_red
# Out:
#     I(nA)   V(V)
# 0      95 -0.161
# 1      90 -0.168
# 2      85 -0.172
# 3      80 -0.176
# 4      75 -0.179
# 5      70 -0.184
# 6      65 -0.189
# 7      60 -0.193
# 8      55 -0.197
# 9      50 -0.201
# 10     45 -0.207
# 11     40 -0.214
# 12     35 -0.219
# 13     30 -0.226
# 14     25 -0.233
# 15     20 -0.243
# 16     15 -0.253
# 17     10 -0.263
# 18      5 -0.276
# 19      0 -0.291

# %%
current_red = data_red["I(nA)"]
potential_red = data_red["V(V)"]
plt.scatter(potential_red, current_red)
plt.xlabel("Voltaje (V)")
plt.ylabel("Corriente (nA)")
plt.title("Voltaje vs Corriente LED Rojo")
# Out:
# Text(0.5, 1.0, 'Voltaje vs Corriente LED Rojo')

# %%
data_azul = pd.read_excel(r"C:\Users\LENOVO\Documents\Computador Nuevo JP\UNIANDES\CUARTO SEMESTRE\LAB. FISICA MODERNA\Datos 1 - Efecto Fotoeléctrico (Parte 1) - copia.xlsx",2)
data_azul
# Out:
#     I(nA)   V(V)
# 0      95 -0.696
# 1      90 -0.697
# 2      85 -0.698
# 3      80 -0.699
# 4      75 -0.699
# 5      70 -0.700
# 6      65 -0.701
# 7      60 -0.702
# 8      55 -0.703
# 9      50 -0.703
# 10     45 -0.704
# 11     40 -0.705
# 12     35 -0.706
# 13     30 -0.706
# 14     25 -0.707
# 15     20 -0.708
# 16     15 -0.708
# 17     10 -0.709
# 18      5 -0.710
# 19      0 -0.711

# %%
current_azul = data_azul["I(nA)"]
potential_azul = data_azul["V(V)"]
plt.scatter(potential_azul, current_azul)
plt.xlabel("Voltaje (V)")
plt.ylabel("Corriente (nA)")
plt.title("Voltaje vs Corriente LED Azul")
# Out:
# Text(0.5, 1.0, 'Voltaje vs Corriente LED Azul')

# %%
data_verde = pd.read_excel(r"C:\Users\LENOVO\Documents\Computador Nuevo JP\UNIANDES\CUARTO SEMESTRE\LAB. FISICA MODERNA\Datos 1 - Efecto Fotoeléctrico (Parte 1) - copia.xlsx",3)
data_verde
# Out:
#     I(nA)   V(V)
# 0      95 -0.587
# 1      90 -0.588
# 2      85 -0.591
# 3      80 -0.592
# 4      75 -0.594
# 5      70 -0.597
# 6      65 -0.599
# 7      60 -0.600
# 8      55 -0.601
# 9      50 -0.604
# 10     45 -0.606
# 11     40 -0.608
# 12     35 -0.610
# 13     30 -0.612
# 14     25 -0.614
# 15     20 -0.616
# 16     15 -0.619
# 17     10 -0.622
# 18      5 -0.624
# 19      0 -0.627

# %%
current_verde = data_verde["I(nA)"]
potential_verde = data_verde["V(V)"]
plt.scatter(potential_verde, current_verde)
plt.xlabel("Voltaje (V)")
plt.ylabel("Corriente (nA)")
plt.title("Voltaje vs Corriente LED Verde")
# Out:
# Text(0.5, 1.0, 'Voltaje vs Corriente LED Verde')
